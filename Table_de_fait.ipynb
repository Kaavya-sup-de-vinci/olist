# %%
import pandas as pd

# %%
customers = pd.read_csv("olist_customers_dataset.csv")
geolocalisation =  pd.read_csv("olist_geolocation_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
payments = pd.read_csv("olist_order_payments_dataset.csv")
reviews = pd.read_csv("olist_order_reviews_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
product_category = pd.read_csv("product_category_name_translation.csv")

# %%
products.head(20)
# Out:
#                           product_id             product_category_name  \
# 0   1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1   3aa071139cb16b67ca9e5dea641aaa2f                             artes
# 2   96bd76ec8810374ed1b65e291975717f                     esporte_lazer
# 3   cef67bcfe19066a932b7673e239eb23d                             bebes
# 4   9dc1a7de274444849c219cff195d0b71             utilidades_domesticas
# 5   41d3672d4792049fa1779bb35283ed13             instrumentos_musicais
# 6   732bd381ad09e530fe0a5f457d81becb                        cool_stuff
# 7   2548af3e6e77a690cf3eb6368e9ab61e                  moveis_decoracao
# 8   37cc742be07708b53a98702e77a21a02                  eletrodomesticos
# 9   8c92109888e8cdf9d66dc7e463025574                        brinquedos
# 10  14aa47b7fe5c25522b47b4b29c98dcb9                   cama_mesa_banho
# 11  03b63c5fc16691530586ae020c345514                             bebes
# ...

# %%
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
payments[payments["order_id"] == "00018f77f2f0320c557190d7a144bdd3"]
# Out:
#                               order_id  payment_sequential payment_type  \
# 2499  00018f77f2f0320c557190d7a144bdd3                   1  credit_card
#
#       payment_installments  payment_value
# 2499                     3         259.83

# %%
#order_items['quantity'] = (order_items['payment_value'] - order_items['freight_value']) // order_items['price']

# %%
#order_items = order_items.merge(payments[['order_id', 'payment_value']], on='order_id')

#order_items = order_items.merge(products[['product_id', 'product_category_name']], on='product_id')

#order_items['quantity'] = (order_items['payment_value'] - order_items['freight_value']) / order_items['price']

# %%
order_items = order_items.merge(payments[['order_id', 'payment_value']], on='order_id')

order_items['net_payment'] = order_items['payment_value'] - order_items['freight_value']

order_items['quantity_real'] = order_items['net_payment'] / order_items['price']

order_items = order_items[order_items['quantity_real'] % 1 == 0]

order_items['quantity'] = order_items['quantity_real'].astype(int)

order_items = order_items.drop(columns=['net_payment', 'quantity_real'])

# %%
order_items_facts = order_items[order_items["quantity"]>0]

# %%
order_items = order_items.drop(columns="order_item_id")

# %%
order_items[order_items["quantity"]>5]
# Out:
#                                order_id                        product_id  \
# 20186  2c52a5a630ca9e849ec5fad8932bab44  7703b8cb5b77fbb36518ea91e2ca734f
# 20190  2c52a5a630ca9e849ec5fad8932bab44  7703b8cb5b77fbb36518ea91e2ca734f
#
#                               seller_id  shipping_limit_date  price  \
# 20186  6560211a19b47992c3666cc44a7e94c0  2017-03-23 14:41:46   39.0
# 20190  6560211a19b47992c3666cc44a7e94c0  2017-03-23 14:41:46   39.0
#
#        freight_value  payment_value  quantity
# 20186           10.0          244.0         6
# 20190           10.0          244.0         6

# %%
order_items_facts = order_items_facts.drop_duplicates(subset="order_id",keep='first')

# %%
order_items_facts.head(10)
# Out:
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 6   00054e8431b9d7675808bcb819fb4a32              1
# 7   000576fe39319847cbb9d288c5617fa6              1
# 8   0005a1a1728c9d785b8e2b08b904576c              1
# 9   0005f50442cb953dcd1d21e1fb923495              1
# 10  00061f2a7bc09da83e415a52dc8a4af1              1
# 11  00063b381e2406b52ad429470734ebd5              1
# 12  0006ec9db01a64e59a68b2c340bf65a7              1
# 15  0009792311464db532ff765bf7b182ae              1
#
#                           product_id                         seller_id  \
# 0   4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2   c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 6   8d4f2bb7e93e6710a28f34fa83ee7d28  7040e82f899a04d1b434b795a43b4617
# 7   557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# ...

# %%
fact_sales_test = order_items_facts.merge(orders, on="order_id",how="inner")

# %%
fact_sales = fact_sale[["order_id","customer_id","product_id","seller_id","payment_value","order_approved_at","quantity"]]

# %%
fact_sales["Date_id"] = fact_sales["order_id"] + "/" + fact_sales["order_approved_at"]
# Out:
# C:\Users\boral\AppData\Local\Temp\ipykernel_29076\1632870605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fact_sales["Date_id"] = fact_sales["order_id"] + "/" + fact_sales["order_approved_at"]

# %%
fact_sales.drop(columns="order_approved_at",inplace=True)
# Out:
# C:\Users\boral\AppData\Local\Temp\ipykernel_29076\2461134544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fact_sales.drop(columns="order_approved_at",inplace=True)

# %%
fact_sales.to_csv("fact_Sales.csv")

# %%
# Informations de connexion à la base PostgreSQL distante
import os
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.exc import OperationalError
 


user = 'ETUDIANT'
password = 'it_L3@rninge'
host = 'localhost'  # Par exemple : '192.168.1.100'
port = '5432'              # Par défaut pour PostgreSQL
database = 'olist_dwh'
 
# Création du moteur de connexion
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')
 
# Envoi du DataFrame vers PostgreSQL
fact_sales.to_sql('fact_sales', engine, if_exists='replace', index=False)
 
print("DataFrame envoyé avec succès !")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[286], line 19
#      16 engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')
#      18 # Envoi du DataFrame vers PostgreSQL
# ---> 19 fact_sales.to_sql('fact_sales', engine, if_exists='replace', index=False)
#      21 print("DataFrame envoyé avec succès !")
#
# File c:\Users\boral\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
